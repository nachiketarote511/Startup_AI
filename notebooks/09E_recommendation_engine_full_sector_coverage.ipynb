# %%
import pandas as pd
import numpy as np
import joblib
import json

df = pd.read_csv(
    "../datasets/cleaned/startup_info.csv",
    low_memory=False
)

print(df.shape)
# Out:
# (50000, 116)

# %%
sector_weakness_templates = {}

# %%
sector_weakness_templates["FinTech"] = {

"Founder Strength":[
"Add ex-banking advisor",
"Build fintech compliance expertise",
"Hire fintech product leader",
"Expand financial industry network",
"Strengthen regulatory knowledge"
],

"Funding Strength":[
"Target fintech investors",
"Improve financial metrics",
"Increase transaction volume",
"Prepare institutional funding",
"Strengthen investor reporting"
],

"Growth":[
"Increase merchant acquisition",
"Improve transaction volume",
"Expand lending products",
"Increase customer retention",
"Expand payment ecosystem"
],

"Market Opportunity":[
"Expand SME customer segment",
"Enter new financial verticals",
"Increase regional penetration",
"Launch new financial products",
"Expand ecosystem partnerships"
]

}

# %%
sector_weakness_templates["HealthTech"] = {

"Founder Strength":[
"Add healthcare advisor",
"Partner with medical experts",
"Build healthcare compliance team",
"Expand doctor network",
"Improve healthcare expertise"
],

"Funding Strength":[
"Target healthcare investors",
"Improve clinical validation",
"Strengthen healthcare partnerships",
"Increase hospital adoption",
"Improve investor readiness"
],

"Growth":[
"Partner with hospitals",
"Increase doctor onboarding",
"Improve patient retention",
"Expand healthcare reach",
"Increase platform adoption"
],

"Market Opportunity":[
"Expand telemedicine reach",
"Target new healthcare segments",
"Increase rural penetration",
"Launch healthcare programs",
"Expand patient ecosystem"
]

}

# %%
sector_weakness_templates["SaaS"] = {

"Founder Strength":[
"Hire SaaS growth advisor",
"Strengthen B2B sales leadership",
"Improve product strategy",
"Expand SaaS network",
"Build executive team"
],

"Funding Strength":[
"Increase MRR",
"Improve SaaS metrics",
"Strengthen recurring revenue",
"Target SaaS investors",
"Improve unit economics"
],

"Growth":[
"Reduce churn",
"Increase MRR",
"Improve free-to-paid conversion",
"Expand acquisition channels",
"Improve onboarding"
],

"Market Opportunity":[
"Target enterprise customers",
"Expand global reach",
"Launch new SaaS modules",
"Expand integrations",
"Increase customer segments"
]

}

# %%
sector_weakness_templates["AI"] = {

"Founder Strength":[
"Add AI research advisor",
"Strengthen AI expertise",
"Hire ML leadership",
"Expand AI partnerships",
"Increase technical depth"
],

"Funding Strength":[
"Target AI-focused investors",
"Improve AI product traction",
"Increase enterprise adoption",
"Strengthen AI roadmap",
"Improve valuation metrics"
],

"Growth":[
"Increase API adoption",
"Expand enterprise clients",
"Improve model performance",
"Increase AI use-cases",
"Strengthen partnerships"
],

"Market Opportunity":[
"Expand AI verticals",
"Target enterprise sectors",
"Launch industry-specific AI",
"Increase global reach",
"Build ecosystem partnerships"
]

}

# %%
sector_weakness_templates["EdTech"] = {

"Founder Strength":[
"Add education industry advisor",
"Partner with academic experts",
"Build curriculum leadership",
"Expand institutional network",
"Improve education expertise"
],

"Funding Strength":[
"Target EdTech investors",
"Increase learner retention metrics",
"Improve course monetization",
"Strengthen institutional partnerships",
"Improve funding readiness"
],

"Growth":[
"Increase student retention",
"Expand course catalog",
"Improve paid enrollments",
"Partner with institutes",
"Improve completion rates"
],

"Market Opportunity":[
"Expand professional learning segment",
"Target schools and colleges",
"Launch certification programs",
"Expand international learners",
"Increase enterprise training"
]
}

# %%
sector_weakness_templates["Retail"] = {

"Founder Strength":[
"Add retail operations advisor",
"Improve merchandising expertise",
"Expand supplier network",
"Strengthen retail leadership",
"Improve customer experience strategy"
],

"Funding Strength":[
"Increase store profitability",
"Improve inventory turnover",
"Target retail investors",
"Improve margins",
"Strengthen investor reporting"
],

"Growth":[
"Increase repeat purchases",
"Expand store network",
"Improve customer retention",
"Launch loyalty programs",
"Improve omnichannel presence"
],

"Market Opportunity":[
"Expand product categories",
"Target new demographics",
"Increase regional expansion",
"Launch premium offerings",
"Expand distribution reach"
]
}

# %%
sector_weakness_templates["AgriTech"] = {

"Founder Strength":[
"Add agriculture advisor",
"Expand farmer network",
"Build agri expertise",
"Partner with agronomists",
"Improve rural market knowledge"
],

"Funding Strength":[
"Target impact investors",
"Improve adoption metrics",
"Strengthen government partnerships",
"Improve unit economics",
"Increase investor visibility"
],

"Growth":[
"Expand farmer acquisition",
"Increase product adoption",
"Strengthen distribution network",
"Improve retention",
"Expand rural reach"
],

"Market Opportunity":[
"Expand crop coverage",
"Enter new regions",
"Launch agri-finance products",
"Expand supply chain services",
"Increase ecosystem reach"
]
}

# %%
sector_weakness_templates["E-Commerce"] = {

"Founder Strength":[
"Add e-commerce advisor",
"Improve marketplace expertise",
"Expand seller network",
"Strengthen operations",
"Improve customer experience"
],

"Funding Strength":[
"Improve GMV",
"Increase repeat orders",
"Target commerce investors",
"Improve margins",
"Strengthen unit economics"
],

"Growth":[
"Reduce cart abandonment",
"Increase repeat purchases",
"Improve retention",
"Expand acquisition channels",
"Improve conversion rates"
],

"Market Opportunity":[
"Expand product categories",
"Target Tier-2 cities",
"Expand seller ecosystem",
"Increase regional presence",
"Launch new verticals"
]
}

# %%
sector_weakness_templates["CleanTech"] = {

"Founder Strength":[
"Add sustainability advisor",
"Build climate expertise",
"Expand industry partnerships",
"Strengthen technical leadership",
"Improve policy knowledge"
],

"Funding Strength":[
"Target ESG investors",
"Improve impact metrics",
"Strengthen grant applications",
"Improve investor readiness",
"Increase visibility"
],

"Growth":[
"Increase adoption",
"Expand partnerships",
"Improve customer retention",
"Scale deployment",
"Expand distribution"
],

"Market Opportunity":[
"Expand green solutions",
"Target enterprise customers",
"Enter new markets",
"Increase climate impact",
"Expand ecosystem reach"
]
}

# %%
sector_weakness_templates["PropTech"] = {

"Founder Strength":[
"Add real-estate advisor",
"Expand developer network",
"Improve property expertise",
"Strengthen leadership",
"Increase industry presence"
],

"Funding Strength":[
"Target proptech investors",
"Improve transaction metrics",
"Strengthen partnerships",
"Improve revenue model",
"Increase investor confidence"
],

"Growth":[
"Expand property listings",
"Increase customer acquisition",
"Improve retention",
"Expand broker network",
"Increase transaction volume"
],

"Market Opportunity":[
"Expand commercial real estate",
"Enter new cities",
"Launch new services",
"Expand ecosystem reach",
"Increase market penetration"
]
}

# %%
sector_weakness_templates["Gaming"] = {

"Founder Strength":[
"Add gaming advisor",
"Expand gaming partnerships",
"Improve product leadership",
"Strengthen creative team",
"Build gaming expertise"
],

"Funding Strength":[
"Target gaming investors",
"Improve engagement metrics",
"Increase monetization",
"Strengthen revenue model",
"Improve investor readiness"
],

"Growth":[
"Increase DAU",
"Improve retention",
"Expand player base",
"Improve engagement",
"Launch new content"
],

"Market Opportunity":[
"Expand gaming genres",
"Enter global markets",
"Launch esports initiatives",
"Expand platform reach",
"Increase audience segments"
]
}

# %%
sector_weakness_templates["FoodTech"] = {

"Founder Strength":[
"Add food industry advisor",
"Expand restaurant network",
"Improve supply expertise",
"Strengthen operations",
"Increase domain knowledge"
],

"Funding Strength":[
"Target foodtech investors",
"Improve order metrics",
"Increase retention",
"Improve unit economics",
"Strengthen reporting"
],

"Growth":[
"Increase order frequency",
"Expand restaurant partners",
"Improve retention",
"Increase customer acquisition",
"Improve delivery efficiency"
],

"Market Opportunity":[
"Expand cuisine categories",
"Enter new cities",
"Increase cloud kitchen presence",
"Expand partnerships",
"Increase market penetration"
]
}

# %%
sector_weakness_templates["TravelTech"] = {

"Founder Strength":[
"Add travel industry advisor",
"Expand tourism partnerships",
"Improve travel expertise",
"Strengthen leadership",
"Increase ecosystem presence"
],

"Funding Strength":[
"Target travel investors",
"Improve booking metrics",
"Increase repeat users",
"Improve margins",
"Strengthen investor confidence"
],

"Growth":[
"Increase bookings",
"Improve retention",
"Expand acquisition channels",
"Launch loyalty programs",
"Increase partnerships"
],

"Market Opportunity":[
"Expand destinations",
"Enter international markets",
"Launch travel packages",
"Increase customer segments",
"Expand ecosystem reach"
]
}

# %%
sector_weakness_templates["Logistics"] = {

"Founder Strength":[
"Add logistics industry expert",
"Improve supply chain leadership",
"Expand logistics partnerships",
"Build operational expertise",
"Strengthen logistics network"
],

"Funding Strength":[
"Improve delivery metrics",
"Increase logistics efficiency",
"Strengthen investor reporting",
"Improve profit margins",
"Target logistics investors"
],

"Growth":[
"Expand delivery network",
"Increase shipment volume",
"Improve customer retention",
"Expand B2B partnerships",
"Improve operational efficiency"
],

"Market Opportunity":[
"Expand regional coverage",
"Launch warehousing services",
"Increase last-mile presence",
"Target enterprise logistics",
"Expand ecosystem partnerships"
]

}

# %%
sector_weakness_templates["Cybersecurity"] = {

"Founder Strength":[
"Add cybersecurity advisor",
"Improve security expertise",
"Expand enterprise network",
"Build compliance leadership",
"Strengthen technical depth"
],

"Funding Strength":[
"Target cybersecurity investors",
"Increase enterprise contracts",
"Improve ARR metrics",
"Strengthen recurring revenue",
"Improve valuation metrics"
],

"Growth":[
"Increase enterprise adoption",
"Expand security offerings",
"Improve customer retention",
"Increase annual contracts",
"Expand partner network"
],

"Market Opportunity":[
"Target regulated industries",
"Expand global markets",
"Launch compliance products",
"Increase enterprise penetration",
"Expand ecosystem reach"
]

}

# %%
print(len(sector_weakness_templates))
print(sector_weakness_templates.keys())
# Out:
# 15
# dict_keys(['FinTech', 'HealthTech', 'SaaS', 'AI', 'EdTech', 'Retail', 'AgriTech', 'E-Commerce', 'CleanTech', 'PropTech', 'Gaming', 'FoodTech', 'TravelTech', 'Logistics', 'Cybersecurity'])

# %%
def generate_v4(row):

    sector = row["sector"]
    weakness = row["weakness_1"]

    if (
        sector in sector_weakness_templates
        and
        weakness in sector_weakness_templates[sector]
    ):

        recs = sector_weakness_templates[
            sector
        ][weakness]

    else:

        recs = generic_templates[
            weakness
        ]

    return (

        recs[0],
        recs[1],
        recs[2],
        recs[3],
        recs[4],

        " → ".join(
            recs[:3]
        )

    )

# %%
results = df.apply(
    generate_v4,
    axis=1
)

# %%
df["v5_rec_1"] = [x[0] for x in results]
df["v5_rec_2"] = [x[1] for x in results]
df["v5_rec_3"] = [x[2] for x in results]
df["v5_rec_4"] = [x[3] for x in results]
df["v5_rec_5"] = [x[4] for x in results]

df["v5_roadmap"] = [x[5] for x in results]

# %%
df.to_csv(
    "../datasets/cleaned/startup_info.csv",
    index=False
)

print("V5 Saved ✅")
# Out:
# V5 Saved ✅

# %%
engine = {
    "engine_name": "Full Sector Coverage Recommendation Engine",
    "version": "V5",
    "supported_sectors": 15
}

joblib.dump(
    engine,
    "../models/recommendation_model/full_sector_recommendation_engine.pkl"
)
# Out:
# ['../models/recommendation_model/full_sector_recommendation_engine.pkl']

# %%
metadata = {
    "engine_name": "Full Sector Coverage Recommendation Engine",
    "version": "V5",
    "total_sectors": 15,
    "weakness_types": 4
}

with open(
    "../models/recommendation_model/v5_metadata.json",
    "w"
) as f:
    json.dump(metadata, f, indent=4)

# %%
print(sector_weakness_templates.keys())
# Out:
# dict_keys(['FinTech', 'HealthTech', 'SaaS', 'AI', 'EdTech', 'Retail', 'AgriTech', 'E-Commerce', 'CleanTech', 'PropTech', 'Gaming', 'FoodTech', 'TravelTech', 'Logistics', 'Cybersecurity'])

# %%
print("Total Sectors Covered:")

print(
    len(
        sector_weakness_templates
    )
)

print("\nSectors:\n")

for s in sector_weakness_templates.keys():
    print(s)
# Out:
# Total Sectors Covered:
# 15
#
# Sectors:
#
# FinTech
# HealthTech
# SaaS
# AI
# EdTech
# Retail
# AgriTech
# E-Commerce
# CleanTech
# PropTech
# Gaming
# FoodTech
# TravelTech
# Logistics
# Cybersecurity

# %%
all_sectors = set(
    df["sector"].unique()
)

covered = set(
    sector_weakness_templates.keys()
)

missing = all_sectors - covered

print(
    "Missing Sectors:\n"
)

print(missing)
# Out:
# Missing Sectors:
#
# set()

# %%
print(
    df["v5_rec_1"]
    .value_counts()
    .head(20)
)
# Out:
# v5_rec_1
# Expand product categories               5175
# Expand professional learning segment    2623
# Expand crop coverage                    2581
# Target enterprise customers             2568
# Expand green solutions                  2564
# Target regulated industries             2560
# Expand SME customer segment             2529
# Expand AI verticals                     2528
# Expand regional coverage                2517
# Expand gaming genres                    2509
# Expand cuisine categories               2500
# Expand commercial real estate           2483
# Expand destinations                     2451
# Expand telemedicine reach               2440
# Add retail operations advisor            399
# Add real-estate advisor                  397
# Add agriculture advisor                  386
# Add food industry advisor                384
# Add logistics industry expert            377
# Add AI research advisor                  375
# Name: count, dtype: int64

# %%
for sector in [

    "FinTech",
    "HealthTech",
    "AI",
    "SaaS",
    "Logistics",
    "Cybersecurity"

]:

    print("\n")
    print("="*50)

    print(sector)

    print("="*50)

    sample = df[
        df["sector"] == sector
    ][[
        "sector",
        "weakness_1",
        "v5_rec_1",
        "v5_rec_2",
        "v5_rec_3"
    ]].head(3)

    print(sample)
# Out:
# ...
# FinTech
# ...
#      sector        weakness_1                v5_rec_1  \
# 13  FinTech  Founder Strength  Add ex-banking advisor
# 14  FinTech  Founder Strength  Add ex-banking advisor
# 29  FinTech  Founder Strength  Add ex-banking advisor
#
#                               v5_rec_2                     v5_rec_3
# 13  Build fintech compliance expertise  Hire fintech product leader
# 14  Build fintech compliance expertise  Hire fintech product leader
# 29  Build fintech compliance expertise  Hire fintech product leader
#
#
# ...
# HealthTech
# ...
#         sector        weakness_1                v5_rec_1  \
# 2   HealthTech  Founder Strength  Add healthcare advisor
# 15  HealthTech  Founder Strength  Add healthcare advisor
# 19  HealthTech  Founder Strength  Add healthcare advisor
#
#                         v5_rec_2                          v5_rec_3
# 2   Partner with medical experts  Build healthcare compliance team
# 15  Partner with medical experts  Build healthcare compliance team
# ...

# %%
df[[
    "sector",
    "weakness_1",
    "v5_roadmap"
]].sample(20)
# Out:
#            sector          weakness_1  \
# 10053    PropTech  Market Opportunity
# 15949        SaaS              Growth
# 19816  E-Commerce  Market Opportunity
# 36932    FoodTech    Founder Strength
# 23244   Logistics    Funding Strength
# 30501      Gaming    Funding Strength
# 40068    PropTech  Market Opportunity
# 31885      EdTech  Market Opportunity
# 17543        SaaS    Founder Strength
# 39278    FoodTech              Growth
# 357     CleanTech    Founder Strength
# 16670    AgriTech    Funding Strength
# 40307   Logistics  Market Opportunity
# 19415  HealthTech  Market Opportunity
# 15306      Gaming  Market Opportunity
# 2682    CleanTech  Market Opportunity
# 20325  TravelTech  Market Opportunity
# 20928    AgriTech    Founder Strength
# 36121    PropTech  Market Opportunity
# 19865      EdTech  Market Opportunity
#
#                                               v5_roadmap
# 10053  Expand commercial real estate → Enter new citi...
# ...

# %%
print(
    "Unique Recommendation 1:",
    df["v5_rec_1"].nunique()
)

print(
    "Unique Recommendation 2:",
    df["v5_rec_2"].nunique()
)

print(
    "Unique Recommendation 3:",
    df["v5_rec_3"].nunique()
)
# Out:
# Unique Recommendation 1: 59
# Unique Recommendation 2: 58
# Unique Recommendation 3: 55

# %%
print(len(sector_weakness_templates))

print(missing)

print(df["v5_rec_1"].nunique())

print(df["v5_rec_1"].value_counts().head(10))
# Out:
# 15
# set()
# 59
# v5_rec_1
# Expand product categories               5175
# Expand professional learning segment    2623
# Expand crop coverage                    2581
# Target enterprise customers             2568
# Expand green solutions                  2564
# Target regulated industries             2560
# Expand SME customer segment             2529
# Expand AI verticals                     2528
# Expand regional coverage                2517
# Expand gaming genres                    2509
# Name: count, dtype: int64
